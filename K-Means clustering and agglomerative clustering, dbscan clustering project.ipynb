# %%
import pandas as pd

# %%
flipkart=pd.read_csv('C:\\Users\\bharg\\Desktop\\Bhargav\Flipkart_Mobiles.csv')
flipkart
# Out:
#         Brand   Model            Color Memory Storage  Rating  Selling Price  \
# 0        OPPO     A53  Moonlight Black   4 GB   64 GB     4.5          11990
# 1        OPPO     A53       Mint Cream   4 GB   64 GB     4.5          11990
# 2        OPPO     A53  Moonlight Black   6 GB  128 GB     4.3          13990
# 3        OPPO     A53       Mint Cream   6 GB  128 GB     4.3          13990
# 4        OPPO     A53   Electric Black   4 GB   64 GB     4.5          11990
# ...       ...     ...              ...    ...     ...     ...            ...
# 3109  SAMSUNG  M52 5G    Blazing Black   6 GB  128 GB     4.3          25990
# 3110  SAMSUNG  M52 5G         Icy Blue   6 GB  128 GB     4.3          25489
# 3111  SAMSUNG  M52 5G         Icy Blue   8 GB  128 GB     4.3          27239
# 3112  SAMSUNG  M52 5G      Slate Black   8 GB  128 GB     4.2          22989
# 3113  SAMSUNG  M52 5G         Sky Blue   8 GB  128 GB     4.2          20350
#
#       Original Price
# 0              15990
# ...

# %%
flipkart.duplicated().sum()
# Out:
# 108

# %%
flipkart=flipkart.drop_duplicates()
flipkart
# Out:
#         Brand   Model            Color Memory Storage  Rating  Selling Price  \
# 0        OPPO     A53  Moonlight Black   4 GB   64 GB     4.5          11990
# 1        OPPO     A53       Mint Cream   4 GB   64 GB     4.5          11990
# 2        OPPO     A53  Moonlight Black   6 GB  128 GB     4.3          13990
# 3        OPPO     A53       Mint Cream   6 GB  128 GB     4.3          13990
# 4        OPPO     A53   Electric Black   4 GB   64 GB     4.5          11990
# ...       ...     ...              ...    ...     ...     ...            ...
# 3109  SAMSUNG  M52 5G    Blazing Black   6 GB  128 GB     4.3          25990
# 3110  SAMSUNG  M52 5G         Icy Blue   6 GB  128 GB     4.3          25489
# 3111  SAMSUNG  M52 5G         Icy Blue   8 GB  128 GB     4.3          27239
# 3112  SAMSUNG  M52 5G      Slate Black   8 GB  128 GB     4.2          22989
# 3113  SAMSUNG  M52 5G         Sky Blue   8 GB  128 GB     4.2          20350
#
#       Original Price
# 0              15990
# ...

# %%
flipkart.duplicated().sum()
# Out:
# 0

# %%
flipkart.isnull().sum()
# Out:
# Brand               0
# Model               0
# Color               0
# Memory             40
# Storage            39
# Rating            130
# Selling Price       0
# Original Price      0
# dtype: int64

# %%
numerical=[fea for fea in flipkart.columns if flipkart[fea].dtypes!=object]
numerical
# Out:
# ['Rating', 'Selling Price', 'Original Price']

# %%
categorical=[fea for fea in flipkart.columns if flipkart[fea].dtypes==object]
categorical
# Out:
# ['Brand', 'Model', 'Color', 'Memory', 'Storage']

# %%
numerical=flipkart[numerical]
numerical
# Out:
#       Rating  Selling Price  Original Price
# 0        4.5          11990           15990
# 1        4.5          11990           15990
# 2        4.3          13990           17990
# 3        4.3          13990           17990
# 4        4.5          11990           15990
# ...      ...            ...             ...
# 3109     4.3          25990           25990
# 3110     4.3          25489           28449
# 3111     4.3          27239           31489
# 3112     4.2          22989           22989
# 3113     4.2          20350           22595
#
# [3006 rows x 3 columns]

# %%
categorical=flipkart[categorical]
categorical
# Out:
#         Brand   Model            Color Memory Storage
# 0        OPPO     A53  Moonlight Black   4 GB   64 GB
# 1        OPPO     A53       Mint Cream   4 GB   64 GB
# 2        OPPO     A53  Moonlight Black   6 GB  128 GB
# 3        OPPO     A53       Mint Cream   6 GB  128 GB
# 4        OPPO     A53   Electric Black   4 GB   64 GB
# ...       ...     ...              ...    ...     ...
# 3109  SAMSUNG  M52 5G    Blazing Black   6 GB  128 GB
# 3110  SAMSUNG  M52 5G         Icy Blue   6 GB  128 GB
# 3111  SAMSUNG  M52 5G         Icy Blue   8 GB  128 GB
# 3112  SAMSUNG  M52 5G      Slate Black   8 GB  128 GB
# 3113  SAMSUNG  M52 5G         Sky Blue   8 GB  128 GB
#
# [3006 rows x 5 columns]

# %%
flipkartnumerical=numerical.fillna(numerical.mean())
flipkartnumerical
# Out:
#       Rating  Selling Price  Original Price
# 0        4.5          11990           15990
# 1        4.5          11990           15990
# 2        4.3          13990           17990
# 3        4.3          13990           17990
# 4        4.5          11990           15990
# ...      ...            ...             ...
# 3109     4.3          25990           25990
# 3110     4.3          25489           28449
# 3111     4.3          27239           31489
# 3112     4.2          22989           22989
# 3113     4.2          20350           22595
#
# [3006 rows x 3 columns]

# %%
flipkartcategorical=categorical.fillna(categorical.mode().iloc[0])
flipkartcategorical
# Out:
#         Brand   Model            Color Memory Storage
# 0        OPPO     A53  Moonlight Black   4 GB   64 GB
# 1        OPPO     A53       Mint Cream   4 GB   64 GB
# 2        OPPO     A53  Moonlight Black   6 GB  128 GB
# 3        OPPO     A53       Mint Cream   6 GB  128 GB
# 4        OPPO     A53   Electric Black   4 GB   64 GB
# ...       ...     ...              ...    ...     ...
# 3109  SAMSUNG  M52 5G    Blazing Black   6 GB  128 GB
# 3110  SAMSUNG  M52 5G         Icy Blue   6 GB  128 GB
# 3111  SAMSUNG  M52 5G         Icy Blue   8 GB  128 GB
# 3112  SAMSUNG  M52 5G      Slate Black   8 GB  128 GB
# 3113  SAMSUNG  M52 5G         Sky Blue   8 GB  128 GB
#
# [3006 rows x 5 columns]

# %%
flipkartnumerical.isnull().sum()
# Out:
# Rating            0
# Selling Price     0
# Original Price    0
# dtype: int64

# %%
flipkartcategorical.isnull().sum()
# Out:
# Brand      0
# Model      0
# Color      0
# Memory     0
# Storage    0
# dtype: int64

# %%
from sklearn.cluster import KMeans

# %%
r=[]
w=range(1,10)
for i in w:
    k=KMeans(n_clusters=i)
    k.fit(flipkartnumerical[['Rating','Selling Price']])
    r.append(k.inertia_)

# %%
import matplotlib.pyplot as plt
plt.plot(w,r)

# %% [markdown]
# # so asper elbow diagram k=2 is good

# %%
from sklearn.cluster import KMeans
k=KMeans(n_clusters=2)

# %%
k.fit(flipkartnumerical[['Rating','Selling Price']])
# Out:
# KMeans(n_clusters=2)

# %%
r=k.predict(flipkartnumerical[['Rating','Selling Price']])
r
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
k.cluster_centers_
# Out:
# array([[4.20359974e+00, 1.64867195e+04],
#        [4.46872638e+00, 9.29087880e+04]])

# %%
flipkartnumerical['cluster']=r
flipkartnumerical
# Out:
#       Rating  Selling Price  Original Price  cluster
# 0        4.5          11990           15990        0
# 1        4.5          11990           15990        0
# 2        4.3          13990           17990        0
# 3        4.3          13990           17990        0
# 4        4.5          11990           15990        0
# ...      ...            ...             ...      ...
# 3109     4.3          25990           25990        0
# 3110     4.3          25489           28449        0
# 3111     4.3          27239           31489        0
# 3112     4.2          22989           22989        0
# 3113     4.2          20350           22595        0
#
# [3006 rows x 4 columns]

# %%
n=flipkartnumerical[flipkartnumerical['cluster']==0]
l=flipkartnumerical[flipkartnumerical['cluster']==1]
plt.scatter(n['Rating'],n['Selling Price'],color='red')
plt.scatter(l['Rating'],l['Selling Price'],color='green')
plt.scatter(k.cluster_centers_[:,0],k.cluster_centers_[:,1],color='black',marker='*',label='centroid')
plt.legend()

# %% [markdown]
# # agglomerative clustering

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
from scipy.cluster import hierarchy
from scipy.cluster.hierarchy import dendrogram

# %%
a=AgglomerativeClustering()
p=a.fit_predict(flipkartnumerical[['Rating','Selling Price']])
p
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
u=hierarchy.linkage(a.children_)
u
# Out:
# array([[2.81000000e+02, 2.82000000e+02, 1.41421356e+00, 2.00000000e+00],
#        [7.80000000e+02, 7.81000000e+02, 1.41421356e+00, 2.00000000e+00],
#        [8.28000000e+02, 8.29000000e+02, 1.41421356e+00, 2.00000000e+00],
#        ...,
#        [5.99400000e+03, 6.00500000e+03, 2.61199158e+02, 3.00300000e+03],
#        [2.81700000e+03, 6.00600000e+03, 2.63188146e+02, 3.00400000e+03],
#        [2.70600000e+03, 6.00700000e+03, 2.67720003e+02, 3.00500000e+03]])

# %%
hierarchy.set_link_color_palette(['r','g'])
i=hierarchy.dendrogram(u,truncate_mode='level')

# %% [markdown]
# # comments:
# 1. The agglomerative clustering is bottom-up method here in this hierarchy two clustes merged together based on similarities form a new cluster based on euclidean distance.
# 2. agglomerative clustering is average linkage it calculates average distance of data points between clusters can be calculated.
# 3. In agglomerative clustering distance is average among one cluster with another cluster in hierarchy.
# 4. In the above dendrogram 3 main clusters are formed.

# %%
a=AgglomerativeClustering(n_clusters=3)

# %%
s=a.fit_predict(flipkartnumerical[['Rating','Selling Price']])
s
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
flipkartnumerical['Agglomerative Clustering']=s
flipkartnumerical
# Out:
#       Rating  Selling Price  Original Price  cluster  Agglomerative Clustering
# 0        4.5          11990           15990        0                         0
# 1        4.5          11990           15990        0                         0
# 2        4.3          13990           17990        0                         0
# 3        4.3          13990           17990        0                         0
# 4        4.5          11990           15990        0                         0
# ...      ...            ...             ...      ...                       ...
# 3109     4.3          25990           25990        0                         0
# 3110     4.3          25489           28449        0                         0
# 3111     4.3          27239           31489        0                         0
# 3112     4.2          22989           22989        0                         0
# 3113     4.2          20350           22595        0                         0
#
# [3006 rows x 5 columns]

# %% [markdown]
# # dbscan

# %%
from sklearn.cluster import DBSCAN
import numpy as np
import seaborn as sns

# %%
t=[]
for i in np.linspace(0.001,20,50):
    d=DBSCAN(eps=i,min_samples=5)
    d.fit(flipkartnumerical[['Rating','Selling Price']])
    outliers=np.sum(d.labels_==-1)/len(d.labels_)
    t.append(outliers)

# %%
sns.lineplot(x=np.linspace(0.001,20,50),y=t,color='green',marker='*',markersize=10,markerfacecolor='pink')
# Out:
# <Axes: >

# %% [markdown]
# # so eps 0.2 is good

# %%
u=DBSCAN(eps=0.2,min_samples=4)

# %%
u.fit(flipkartnumerical[['Rating','Selling Price']])
# Out:
# DBSCAN(eps=0.2, min_samples=4)

# %%
b=u.labels_
b
# Out:
# array([ 0,  0,  1, ..., -1, -1, -1], dtype=int64)

# %%
flipkartnumerical['DBSCAN']=b
flipkartnumerical
# Out:
#       Rating  Selling Price  Original Price  cluster  \
# 0        4.5          11990           15990        0
# 1        4.5          11990           15990        0
# 2        4.3          13990           17990        0
# 3        4.3          13990           17990        0
# 4        4.5          11990           15990        0
# ...      ...            ...             ...      ...
# 3109     4.3          25990           25990        0
# 3110     4.3          25489           28449        0
# 3111     4.3          27239           31489        0
# 3112     4.2          22989           22989        0
# 3113     4.2          20350           22595        0
#
#       Agglomerative Clustering  DBSCAN
# 0                            0       0
# 1                            0       0
# 2                            0       1
# 3                            0       1
# 4                            0       0
# ...                        ...     ...
# 3109                         0      17
# ...

# %% [markdown]
# # comments:
# 1. The above dbscan (density-based spatial clustering application with noise) is helps to create cluster for high density data points.
# 2. dbscan uses three main points these are core points,decision points,eps(epsilon).
# 3. Core points are created to make a small cluster with decision points and epsilon distance.
# 4. Decision points are points but not core points but these helps to form a corepoints.
# 5. epsilon is distance between decisison points and core points will be calculated it should be within epsilon criterion to form small cluster.
# 6. If decision points and core points are not in epsilon distance again different core points are created with decision points within epsilon still criterion doesnot meet randomly corepoints and decision points are selected to form small clusters.
# 7. In the above dbscan -1 is outliers and 0 is a decision points where possible to form many core points.
# 8. Remaining points are clusters these are small clusters formed from density cluster.
